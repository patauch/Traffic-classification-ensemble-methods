# %%
import pandas as pd
import seaborn as sns

# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %%
tables = pd.read_hyml("https://en.wikipedia.org/wiki/Moscow")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-d34d2719330b> in <module>
# ----> 1 tables = pd.read_hyml("https://en.wikipedia.org/wiki/Moscow")
#
# ~\Anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'read_hyml'

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/Moscow", header=1)

# %%
table = tables[6]

table
# Out:
#      Year      Pop.       ±%
# 0  1897.0   1038625        —
# 1  1926.0   2019500   +94.4%
# 2  1939.0   4137000  +104.9%
# 3  1959.0   5032000   +21.6%
# 4  1970.0   6941961   +38.0%
# 5  1979.0   7830509   +12.8%
# 6  1989.0   8967332   +14.5%
# 7  2002.0  10382754   +15.8%
# 8  2010.0  11503501   +10.8%
# 9  2018.0  12506468    +8.7%

# %%
table.drop(10, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-7614b36ca10d> in <module>
# ----> 1 table.drop(10, inplace=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
table.Year = table.Year.astype(float)

# %%
table.rename(columns={'Pop.':'Pop'}, inplace=True)

list(table)

table.Pop = table.Pop.astype(float)
table
# Out:
#      Year         Pop       ±%
# 0  1897.0   1038625.0        —
# 1  1926.0   2019500.0   +94.4%
# 2  1939.0   4137000.0  +104.9%
# 3  1959.0   5032000.0   +21.6%
# 4  1970.0   6941961.0   +38.0%
# 5  1979.0   7830509.0   +12.8%
# 6  1989.0   8967332.0   +14.5%
# 7  2002.0  10382754.0   +15.8%
# 8  2010.0  11503501.0   +10.8%
# 9  2018.0  12506468.0    +8.7%

# %%
table.plot(x='Year', y='Pop')

# %%
sns.lmplot(x='Year',y='Pop',data=table)

# %%
sns.lmplot(x='Year',y='Pop',data=table,order=2)

# %%
from sympy import Symbol, sin, expand

# %%
x = Symbol('x')
y = Symbol('y')

# %%
sin(x).series()
# Out:
# x - x**3/6 + x**5/120 + O(x**6)

# %%
expand((x+y)**10)
# Out:
# x**10 + 10*x**9*y + 45*x**8*y**2 + 120*x**7*y**3 + 210*x**6*y**4 + 252*x**5*y**5 + 210*x**4*y**6 + 120*x**3*y**7 + 45*x**2*y**8 + 10*x*y**9 + y**10

# %%
5**3
# Out:
# 125

# %%
5^4
# Out:
# 1

# %%
5/10
# Out:
# 0.5

# %%
5/4
# Out:
# 1.25

# %%
123//10
# Out:
# 12

# %%
17 % 3
# Out:
# 2

# %%
1 + 2 / 5
# Out:
# 1.4

# %%
5**3**2
# Out:
# 1953125

# %%
5**(3**2)
# Out:
# 1953125

# %%
sqrt(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-317e033d29d5> in <module>
# ----> 1 sqrt(4)
#
# NameError: name 'sqrt' is not defined

# %%
from math import sqrt

# %%
sqrt (4)
# Out:
# 2.0

# %%
import math

# %%
math.sin(0)
math.exp(1)
# Out:
# 2.718281828459045

# %%
import math as m

# %%
m.exp(1)
# Out:
# 2.718281828459045

# %%
from math import*

# %%
sin (pi)
# Out:
# 1.2246467991473532e-16

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
0.1 + 0.2 == 0.3
# Out:
# False

# %%
6+5
12
# Out:
# 12

# %%
a = 12

# %%
a
# Out:
# 12

# %%
a+5
# Out:
# 17

# %%
(a+3)*a
# Out:
# 180

# %%
a=7

# %%
(a+3)*a
# Out:
# 70

# %%
a= a +1

# %%
a
# Out:
# 8

# %%
name = input("Ввведите имя:")
print("hi "+name+"!")
# Out:
# Ввведите имя:awoo
# hi awoo!

# %%
"dsadsadas" + "sdadasd"
# Out:
# 'dsadsadassdadasd'

# %%
a_prev = 1

# %%
a_cur = 1

# %%
a_cur = a_prev + a_cur
a_prev = a_cur - a_prev
print(a_cur)
# Out:
# 21

# %%
a_new = a_prev+ a_cur
a_prev = a_cur
a_cur = a_new
print(a_cur)
# Out:
# 55

# %%
a, b = 5 , 7

# %%
a
# Out:
# 5

# %%
b
# Out:
# 7
